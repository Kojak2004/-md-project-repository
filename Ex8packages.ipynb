# %%
import numpy as np
import matplotlib
import openmm

print("NumPy:", np.__version__)
print("Matplotlib:", matplotlib.__version__)
print("OpenMM:", openmm.__version__)
# Out:
# NumPy: 2.4.6
# Matplotlib: 3.10.9
# OpenMM: 8.5.2
